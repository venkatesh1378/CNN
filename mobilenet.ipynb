# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatesh1378/CNN/blob/main/mobilenet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.mobilenet import preprocess_input,decode_predictions
import numpy as np

# %%
model=MobileNet(weights='imagenet')
# Out:
# ...
# 17225924/17225924 [==============================] - 0s 0us/step

# %%
image_path='/content/bread.jpg'
img=image.load_img(image_path,target_size=(224,224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x=image.img_to_array(img)
x
# Out:
# array([[[ 67.,  41.,  28.],
#         [ 70.,  40.,  29.],
#         [ 59.,  40.,  25.],
#         ...,
#         [ 29.,  18.,  12.],
#         [ 30.,  19.,  13.],
#         [ 27.,  16.,  10.]],
#
#        [[ 69.,  43.,  30.],
#         [ 73.,  43.,  32.],
#         [ 57.,  38.,  23.],
#         ...,
#         [ 30.,  19.,  13.],
#         [ 30.,  19.,  13.],
#         [ 28.,  17.,  11.]],
#
#        [[ 68.,  42.,  29.],
#         [ 73.,  43.,  32.],
#         [ 54.,  35.,  20.],
#         ...,
#         [ 31.,  20.,  14.],
#         [ 31.,  20.,  14.],
#         [ 30.,  19.,  13.]],
#
#        ...,
#
#        [[ 35.,  21.,  21.],
#         [ 32.,  22.,  21.],
#         [ 31.,  26.,  23.],
#         ...,
#         [171., 140., 111.],
#         [182., 157., 126.],
#         [226., 199., 169.]],
#
#        [[ 37.,  23.,  23.],
#         [ 29.,  19.,  18.],
#         [ 25.,  20.,  17.],
#         ...,
#         [141., 110.,  79.],
#         [182., 158., 124.],
# ...

# %%
x=np.expand_dims(x,axis=0)

# %%
x=preprocess_input(x)
x
# Out:
# array([[[[-0.47450978, -0.6784314 , -0.78039217],
#          [-0.45098037, -0.6862745 , -0.77254903],
#          [-0.5372549 , -0.6862745 , -0.8039216 ],
#          ...,
#          [-0.77254903, -0.85882354, -0.90588236],
#          [-0.7647059 , -0.8509804 , -0.8980392 ],
#          [-0.7882353 , -0.8745098 , -0.92156863]],
#
#         [[-0.4588235 , -0.6627451 , -0.7647059 ],
#          [-0.42745095, -0.6627451 , -0.7490196 ],
#          [-0.5529412 , -0.7019608 , -0.81960785],
#          ...,
#          [-0.7647059 , -0.8509804 , -0.8980392 ],
#          [-0.7647059 , -0.8509804 , -0.8980392 ],
#          [-0.78039217, -0.8666667 , -0.9137255 ]],
#
#         [[-0.46666664, -0.67058825, -0.77254903],
#          [-0.42745095, -0.6627451 , -0.7490196 ],
#          [-0.5764706 , -0.7254902 , -0.84313726],
#          ...,
#          [-0.75686276, -0.84313726, -0.8901961 ],
#          [-0.75686276, -0.84313726, -0.8901961 ],
#          [-0.7647059 , -0.8509804 , -0.8980392 ]],
#
# ...

# %%
data=model.predict(x)
k=decode_predictions(data)
# Out:
# 1/1 [==============================] - 0s 55ms/step

# %%
k
# Out:
# [[('n07684084', 'French_loaf', 0.9723928),
#   ('n07614500', 'ice_cream', 0.02344422),
#   ('n07932039', 'eggnog', 0.0013112337),
#   ('n07613480', 'trifle', 0.0006918677),
#   ('n07860988', 'dough', 0.0005124685)]]

# %%
d=k[0][0]

# %%
d[1]
# Out:
# 'French_loaf'
