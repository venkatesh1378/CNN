# %% [markdown]
# <a href="https://colab.research.google.com/github/venkatesh1378/CNN/blob/main/RESNET_50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input,decode_predictions
import numpy as np
import matplotlib.pyplot as plt

# %%
model=ResNet50(weights='imagenet')

# %%
image_path="/content/icecream.jpg"
img=image.load_img(image_path,target_size=(224,224))
x=image.img_to_array(img)
len(x)
# Out:
# 224

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
x=np.expand_dims(x,axis=0)

# %%
x=preprocess_input(x)
len(x)
# Out:
# 1

# %%
x.shape
# Out:
# (1, 224, 224, 3)

# %%
k=model.predict(x)
a=decode_predictions(k)
b=list(a)
b
# Out:
# 1/1 [==============================] - 1s 1s/step
# [[('n07614500', 'ice_cream', 0.27982283),
#   ('n02206856', 'bee', 0.102302976),
#   ('n04026417', 'purse', 0.0976747),
#   ('n13040303', 'stinkhorn', 0.09420475),
#   ('n03709823', 'mailbag', 0.06096486)]]

# %%
class_names=[]
b=list(decode_predictions(k,top=1000))
for i in b:
    for j in i:
      class_names.append(j[1])

# %%
class_names[:5]
# Out:
# ['ice_cream', 'bee', 'purse', 'stinkhorn', 'mailbag']

# %%
class_names[:100]
# Out:
# ['ice_cream',
#  'bee',
#  'purse',
#  'stinkhorn',
#  'mailbag',
#  'toilet_tissue',
#  'orange',
#  'sandal',
#  'quill',
#  'pencil_sharpener',
#  'honeycomb',
#  'sarong',
#  'poncho',
#  'lighter',
#  'Band_Aid',
#  'washbasin',
#  'pinwheel',
#  'thimble',
#  'chambered_nautilus',
#  'pencil_box',
#  'paper_towel',
#  'brassiere',
#  'mask',
#  'plastic_bag',
#  'wallet',
#  'holster',
#  'iron',
#  'perfume',
#  'cowboy_boot',
#  'chocolate_sauce',
#  'umbrella',
#  'miniskirt',
#  'stole',
#  'conch',
#  'cowboy_hat',
#  'feather_boa',
#  'overskirt',
#  'packet',
#  'scabbard',
#  'cup',
#  'lotion',
#  'snail',
#  'shoe_shop',
#  'carton',
#  'microphone',
#  'Loafer',
#  'bucket',
#  'cloak',
#  'teapot',
#  'shower_curtain',
#  'bonnet',
#  'earthstar',
#  'hair_spray',
#  'kimono',
#  'velvet',
#  'buckle',
#  'muzzle',
#  'tick',
#  'banana',
#  'trench_coat',
#  'maillot',
#  'leaf_beetle',
#  'gown',
#  'clog',
#  'bath_towel',
#  'eggnog',
#  'Granny_Smith',
# ...
